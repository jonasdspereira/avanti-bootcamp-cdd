# %%
import pandas as pd

# %%
# ler conjunto de dados do repositório remoto
df = pd.read_csv('https://raw.githubusercontent.com/atlantico-academy/datasets/refs/heads/main/diamonds.csv')
# salvar o conjunto de dados na pasta raw
df = df.to_csv('../data/raw/data.csv')

# %%
# Criar dicionário de dados
data_dictionary = pd.DataFrame([
    {
        'variavel': 'carat',
        'descricao': 'Peso do diamante em quilates',
        'tipo': 'quantitativa',
        'subtipo': 'contínua'
    },
    {
        'variavel': 'cut',
        'descricao': 'Qualidade do corte (Fair, Good, Very Good, Premium, Ideal)',
        'tipo': 'qualitativa',
        'subtipo': 'ordinal'
    },
    {
        'variavel': 'color',
        'descricao': 'Cor do diamante, de J (pior) a D (melhor)',
        'tipo': 'qualitativa',
        'subtipo': 'ordinal'
    },
    {
        'variavel': 'clarity',
        'descricao': 'Claridade do diamante (I1, SI2, SI1, VS2, VS1, VVS2, VVS1, IF)',
        'tipo': 'qualitativa',
        'subtipo': 'ordinal'
    },
    {
        'variavel': 'depth',
        'descricao': 'Profundidade total percentual = z / média(x, y)',
        'tipo': 'quantitativa',
        'subtipo': 'contínua'
    },
    {
        'variavel': 'table',
        'descricao': 'Largura da parte superior do diamante em relação ao ponto mais largo',
        'tipo': 'quantitativa',
        'subtipo': 'contínua'
    },
    {
        'variavel': 'price',
        'descricao': 'Preço em dólares americanos',
        'tipo': 'quantitativa',
        'subtipo': 'discreta'
    },
    {
        'variavel': 'x',
        'descricao': 'Comprimento do diamante em milímetros',
        'tipo': 'quantitativa',
        'subtipo': 'contínua'
    },
    {
        'variavel': 'y',
        'descricao': 'Largura do diamante em milímetros',
        'tipo': 'quantitativa',
        'subtipo': 'contínua'
    },
    {
        'variavel': 'z',
        'descricao': 'Profundidade do diamante em milímetros',
        'tipo': 'quantitativa',
        'subtipo': 'contínua'
    }
])

# Salvar dicionário de dados
data_dictionary.to_csv('../data/external/dictionary.csv', index=False)

# %%
data_dictionary
# Out:
#   variavel                                          descricao          tipo  \
# 0    carat                       Peso do diamante em quilates  quantitativa
# 1      cut  Qualidade do corte (Fair, Good, Very Good, Pre...   qualitativa
# 2    color          Cor do diamante, de J (pior) a D (melhor)   qualitativa
# 3  clarity  Claridade do diamante (I1, SI2, SI1, VS2, VS1,...   qualitativa
# 4    depth    Profundidade total percentual = z / média(x, y)  quantitativa
# 5    table  Largura da parte superior do diamante em relaç...  quantitativa
# 6    price                        Preço em dólares americanos  quantitativa
# 7        x              Comprimento do diamante em milímetros  quantitativa
# 8        y                  Largura do diamante em milímetros  quantitativa
# 9        z             Profundidade do diamante em milímetros  quantitativa
#
#     subtipo
# 0  contínua
# 1   ordinal
# 2   ordinal
# 3   ordinal
# 4  contínua
# 5  contínua
# 6  discreta
# 7  contínua
# ...
